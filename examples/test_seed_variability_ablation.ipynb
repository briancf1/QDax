# %%
# %pip install -U "jax[cuda]"

# %%
# %pip install -U "git+https://github.com/briancf1/QDax.git#egg=qdax[examples]"

# %%
import os
from google.colab import drive
from datetime import datetime

# --- 1. Mount your Google Drive ---
# This will pop up an authorization window the first time.
drive.mount('/content/drive')

# %%
# Clone the repository to get experiment scripts
# !git clone https://github.com/briancf1/QDax.git
# %cd QDax/examples

# %% [markdown]
# ## STEP 1: Setup and Configuration

# %%
import os
import json
import time
from datetime import datetime
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import functools
import warnings
warnings.filterwarnings('ignore')

import jax
import jax.numpy as jnp

from qdax.core.dns_ga import DominatedNoveltySearchGA
from qdax.core.dns import DominatedNoveltySearch
import qdax.tasks.brax as environments
from qdax.tasks.brax.env_creators import scoring_function_brax_envs as scoring_function
from qdax.core.neuroevolution.buffers.buffer import QDTransition
from qdax.core.neuroevolution.networks.networks import MLP
from qdax.core.emitters.mutation_operators import isoline_variation
from qdax.core.emitters.standard_emitters import MixingEmitter
from qdax.utils.metrics import CSVLogger, default_qd_metrics

# Configure plotting
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)

# Create experiment logs directory
os.makedirs("ablation_logs", exist_ok=True)

print("Setup complete!")
print(f"Current directory: {os.getcwd()}")
print(f"JAX devices: {jax.devices()}")
print(f"Start time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Setup complete!
# Current directory: /Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/examples
# JAX devices: [CpuDevice(id=0)]
# Start time: 2025-11-16 12:52:38

# %% [markdown]
# ## Generate Random Seeds (5 seeds for quick ablation)

# %%
# Use first 5 seeds from main study for quick ablation
np.random.seed(2024)
RANDOM_SEEDS = np.random.randint(1, 100000, size=31).tolist()[:5]

print("="*80)
print("ABLATION STUDY: 5 SEEDS FOR GA FREQUENCY SWEEP")
print("="*80)
print(f"Seeds: {RANDOM_SEEDS}")
print(f"Total: {len(RANDOM_SEEDS)} seeds")
print("="*80)

# Save seeds for reproducibility
os.makedirs('ablation_logs', exist_ok=True)
with open('ablation_logs/random_seeds.json', 'w') as f:
    json.dump({'seeds': RANDOM_SEEDS, 'generation_seed': 2024}, f, indent=2)
# Out:
# ================================================================================
# ABLATION STUDY: 5 SEEDS FOR GA FREQUENCY SWEEP
# ================================================================================
# Seeds: [7817, 52731, 51809, 35457, 47644]
# Total: 5 seeds
# ================================================================================

# %% [markdown]
# ## Ablation Configuration: GA Frequency Sweep (g_n)

# %%
FIXED_PARAMS = {
    'batch_size': 100,
    'env_name': 'walker2d_uni',
    'episode_length': 100,
    'num_iterations': 3000,
    'policy_hidden_layer_sizes': (64, 64),
    'population_size': 1024,
    'k': 3,
    'line_sigma': 0.05,
    'iso_sigma': 0.01,
}

# Ablation: Sweep GA frequency (g_n) while keeping generations constant
MAIN_CONFIGS = [
    # Very frequent GA calls
    {
        'type': 'dns-ga',
        'name': 'DNS-GA_g300_gen2',
        'g_n': 300,
        'num_ga_children': 2,
        'num_ga_generations': 2,
    },
    # Medium frequency
    {
        'type': 'dns-ga',
        'name': 'DNS-GA_g500_gen2',
        'g_n': 500,
        'num_ga_children': 2,
        'num_ga_generations': 2,
    },
    # Standard (from main study)
    {
        'type': 'dns-ga',
        'name': 'DNS-GA_g1000_gen2',
        'g_n': 1000,
        'num_ga_children': 2,
        'num_ga_generations': 2,
    },
    # Infrequent GA calls
    {
        'type': 'dns-ga',
        'name': 'DNS-GA_g2000_gen2',
        'g_n': 2000,
        'num_ga_children': 2,
        'num_ga_generations': 2,
    },
]

print("="*80)
print("GA FREQUENCY ABLATION STUDY")
print("="*80)
print(f"Environment: {FIXED_PARAMS['env_name']}")
print(f"Iterations: {FIXED_PARAMS['num_iterations']}")
print(f"Seeds: {len(RANDOM_SEEDS)}")

print(f"\nGA Frequency Sweep (g_n):")
for config in MAIN_CONFIGS:
    ga_calls = FIXED_PARAMS['num_iterations'] // config['g_n']
    print(f"  • g_n={config['g_n']:4d}: {ga_calls:2d} GA calls during 3000 iterations")

total_exp = len(MAIN_CONFIGS) * len(RANDOM_SEEDS)
print(f"\nTotal Experiments: {total_exp}")
print(f"Estimated time (2-parallel): ~{(total_exp / 2) * 13.5 / 60:.1f} hours")
print("="*80)
# Out:
# ================================================================================
# GA FREQUENCY ABLATION STUDY
# ================================================================================
# Environment: walker2d_uni
# Iterations: 3000
# Seeds: 5
#
# GA Frequency Sweep (g_n):
#   • g_n= 300: 10 GA calls during 3000 iterations
#   • g_n= 500:  6 GA calls during 3000 iterations
#   • g_n=1000:  3 GA calls during 3000 iterations
#   • g_n=2000:  1 GA calls during 3000 iterations
#
# Total Experiments: 20
# Estimated time (2-parallel): ~2.2 hours
# ================================================================================

# %% [markdown]
# ## STEP 2: Helper Functions

# %%
def calculate_ga_overhead_evals(g_n, num_iterations, population_size, num_ga_children, num_ga_generations):
    """Calculate total evaluations performed by Competition-GA."""
    if g_n is None or g_n >= num_iterations:
        return 0, 0, 0
    
    num_ga_calls = num_iterations // g_n
    if num_ga_children == 1:
        offspring_per_call = population_size * num_ga_generations
    else:
        offspring_per_call = population_size * num_ga_children * (num_ga_children**num_ga_generations - 1) // (num_ga_children - 1)
    evals_per_ga_call = offspring_per_call
    total_ga_evals = num_ga_calls * evals_per_ga_call
    return total_ga_evals, num_ga_calls, evals_per_ga_call


def setup_environment(env_name, episode_length, policy_hidden_layer_sizes, batch_size, seed):
    """Initialize environment and policy network."""
    env = environments.create(env_name, episode_length=episode_length)
    reset_fn = jax.jit(env.reset)
    key = jax.random.key(seed)
    
    policy_layer_sizes = policy_hidden_layer_sizes + (env.action_size,)
    policy_network = MLP(
        layer_sizes=policy_layer_sizes,
        kernel_init=jax.nn.initializers.lecun_uniform(),
        final_activation=jnp.tanh,
    )
    
    key, subkey = jax.random.split(key)
    keys = jax.random.split(subkey, num=batch_size)
    fake_batch = jnp.zeros(shape=(batch_size, env.observation_size))
    init_variables = jax.vmap(policy_network.init)(keys, fake_batch)
    
    return env, policy_network, reset_fn, init_variables, key


def create_scoring_function(env, policy_network, reset_fn, episode_length, env_name):
    """Create scoring function for fitness evaluation."""
    def play_step_fn(env_state, policy_params, key):
        actions = policy_network.apply(policy_params, env_state.obs)
        state_desc = env_state.info["state_descriptor"]
        next_state = env.step(env_state, actions)
        
        transition = QDTransition(
            obs=env_state.obs,
            next_obs=next_state.obs,
            rewards=next_state.reward,
            dones=next_state.done,
            actions=actions,
            truncations=next_state.info["truncation"],
            state_desc=state_desc,
            next_state_desc=next_state.info["state_descriptor"],
        )
        return next_state, policy_params, key, transition
    
    descriptor_extraction_fn = environments.descriptor_extractor[env_name]
    scoring_fn = functools.partial(
        scoring_function,
        episode_length=episode_length,
        play_reset_fn=reset_fn,
        play_step_fn=play_step_fn,
        descriptor_extractor=descriptor_extraction_fn,
    )
    
    return scoring_fn


def create_mutation_function(iso_sigma):
    """Create mutation function for Competition-GA."""
    def competition_ga_mutation_fn(genotype, key):
        genotype_flat, tree_def = jax.tree_util.tree_flatten(genotype)
        num_leaves = len(genotype_flat)
        keys = jax.random.split(key, num_leaves)
        keys_tree = jax.tree_util.tree_unflatten(tree_def, keys)
        
        def add_noise(x, k):
            return x + jax.random.normal(k, shape=x.shape) * iso_sigma
        
        mutated = jax.tree_util.tree_map(add_noise, genotype, keys_tree)
        return mutated
    
    return competition_ga_mutation_fn


def calculate_cumulative_evals_for_log(config, log_df, batch_size, population_size):
    """Calculate cumulative evaluations at each logged iteration."""
    iterations = log_df['iteration'].values
    evals = np.zeros(len(iterations))
    
    if config['type'] == 'baseline':
        # Baseline: constant batch_size per iteration
        evals = iterations * batch_size
    else:
        # DNS-GA: batch_size + periodic GA overhead
        g_n = config['g_n']
        num_ga_children = config['num_ga_children']
        num_ga_generations = config['num_ga_generations']
        
        # Calculate GA overhead per call
        if g_n >= len(iterations) * 100:  # Sanity check: g_n so large it never triggers
            evals = iterations * batch_size
        elif num_ga_children == 1:
            ga_evals_per_call = population_size * num_ga_generations
            for idx, iter_num in enumerate(iterations):
                cumulative = iter_num * batch_size
                num_ga_calls = iter_num // g_n
                cumulative += num_ga_calls * ga_evals_per_call
                evals[idx] = cumulative
        else:
            ga_evals_per_call = (population_size * num_ga_children * 
                                (num_ga_children**num_ga_generations - 1) // (num_ga_children - 1))
            for idx, iter_num in enumerate(iterations):
                cumulative = iter_num * batch_size
                num_ga_calls = iter_num // g_n
                cumulative += num_ga_calls * ga_evals_per_call
                evals[idx] = cumulative
    
    return evals


def interpolate_evals_to_milestone(qd_scores, evals, milestone):
    """Interpolate evaluations needed to reach a QD score milestone."""
    idx = np.searchsorted(qd_scores, milestone)
    
    if idx == 0:
        return evals[0]
    elif idx >= len(qd_scores):
        return None  # Milestone not reached
    else:
        # Linear interpolation between two points
        qd_low, qd_high = qd_scores[idx-1], qd_scores[idx]
        eval_low, eval_high = evals[idx-1], evals[idx]
        ratio = (milestone - qd_low) / (qd_high - qd_low)
        return eval_low + ratio * (eval_high - eval_low)

print("Helper functions loaded!")
# Out:
# Helper functions loaded!

# %% [markdown]
# ## STEP 3: Parallel Experiment Runner

# %%
def run_single_experiment(config, seed, fixed_params):
    """Run a single experiment with given config and seed."""
    exp_name = f"{config['name']}_seed{seed}"
    
    # Setup environment
    env, policy_network, reset_fn, init_variables, key = setup_environment(
        fixed_params['env_name'],
        fixed_params['episode_length'],
        fixed_params['policy_hidden_layer_sizes'],
        fixed_params['batch_size'],
        seed
    )
    
    scoring_fn = create_scoring_function(env, policy_network, reset_fn, 
                                        fixed_params['episode_length'],
                                        fixed_params['env_name'])
    
    reward_offset = environments.reward_offset[fixed_params['env_name']]
    metrics_function = functools.partial(
        default_qd_metrics,
        qd_offset=reward_offset * fixed_params['episode_length'],
    )
    
    # Create emitter
    variation_fn = functools.partial(
        isoline_variation,
        iso_sigma=fixed_params['iso_sigma'],
        line_sigma=fixed_params['line_sigma']
    )
    
    mixing_emitter = MixingEmitter(
        mutation_fn=None,
        variation_fn=variation_fn,
        variation_percentage=1.0,
        batch_size=fixed_params['batch_size']
    )
    
    # Create algorithm (DNS or DNS-GA)
    if config['type'] == 'baseline':
        algorithm = DominatedNoveltySearch(
            scoring_function=scoring_fn,
            emitter=mixing_emitter,
            metrics_function=metrics_function,
            population_size=fixed_params['population_size'],
            k=fixed_params['k'],
        )
    else:
        mutation_fn = create_mutation_function(fixed_params['iso_sigma'])
        algorithm = DominatedNoveltySearchGA(
            scoring_function=scoring_fn,
            emitter=mixing_emitter,
            metrics_function=metrics_function,
            population_size=fixed_params['population_size'],
            k=fixed_params['k'],
            g_n=config['g_n'],
            num_ga_children=config['num_ga_children'],
            num_ga_generations=config['num_ga_generations'],
            mutation_fn=mutation_fn,
        )
    
    # Initialize
    key, subkey = jax.random.split(key)
    repertoire, emitter_state, init_metrics = algorithm.init(init_variables, subkey)
    
    # Setup logging
    log_period = 100
    num_loops = fixed_params['num_iterations'] // log_period
    
    metrics = {key: jnp.array([]) for key in ["iteration", "qd_score", "coverage", "max_fitness", "time"]}
    init_metrics = jax.tree.map(lambda x: jnp.array([x]) if x.shape == () else x, init_metrics)
    init_metrics["iteration"] = jnp.array([0], dtype=jnp.int32)
    init_metrics["time"] = jnp.array([0.0])
    metrics = jax.tree.map(
        lambda metric, init_metric: jnp.concatenate([metric, init_metric], axis=0),
        metrics, init_metrics
    )
    
    log_filename = os.path.join("ablation_logs", f"{exp_name}_logs.csv")
    csv_logger = CSVLogger(log_filename, header=list(metrics.keys()))
    csv_logger.log(jax.tree.map(lambda x: x[-1], metrics))
    
    # Main training loop
    if config['type'] == 'baseline':
        algorithm_scan_update = algorithm.scan_update
        scan_state = (repertoire, emitter_state, key)
    else:
        algorithm_scan_update = algorithm.scan_update
        scan_state = (repertoire, emitter_state, key, 1)  # generation_counter
    
    start_time_total = time.time()
    
    for i in range(num_loops):
        start_time = time.time()
        
        scan_state, current_metrics = jax.lax.scan(
            algorithm_scan_update,
            scan_state,
            (),
            length=log_period,
        )
        
        timelapse = time.time() - start_time
        
        current_metrics["iteration"] = jnp.arange(
            1 + log_period * i, 1 + log_period * (i + 1), dtype=jnp.int32
        )
        current_metrics["time"] = jnp.repeat(timelapse, log_period)
        metrics = jax.tree.map(
            lambda metric, current_metric: jnp.concatenate([metric, current_metric], axis=0),
            metrics, current_metrics
        )
        
        csv_logger.log(jax.tree.map(lambda x: x[-1], metrics))
    
    total_time = time.time() - start_time_total
    
    # Calculate metrics
    ga_total_evals, ga_num_calls, ga_evals_per_call = calculate_ga_overhead_evals(
        config.get('g_n'), fixed_params['num_iterations'], fixed_params['population_size'],
        config.get('num_ga_children'), config.get('num_ga_generations')
    )
    
    return {
        'config_name': config['name'],
        'config_type': config['type'],
        'seed': seed,
        'g_n': config.get('g_n'),
        'num_ga_generations': config.get('num_ga_generations'),
        'final_qd_score': float(metrics['qd_score'][-1]),
        'final_max_fitness': float(metrics['max_fitness'][-1]),
        'final_coverage': float(metrics['coverage'][-1]),
        'total_time': total_time,
        'ga_overhead_evals': ga_total_evals,
        'log_file': log_filename,
    }

print("Helper functions ready!")
# Out:
# Helper functions ready!

# %% [markdown]
# ## STEP 4: Build Experiment Queue and Execute

# %%
# Build experiment queue
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

print("="*80)
print(f"ABLATION EXPERIMENT QUEUE - {timestamp}")
print("="*80)

experiment_queue = []
exp_num = 0

# Add all experiments (all configs × all seeds)
for config in MAIN_CONFIGS:
    for seed in RANDOM_SEEDS:
        exp_num += 1
        experiment_queue.append((exp_num, exp_num, config, seed))

total_experiments = len(experiment_queue)

print(f"\nExperiment Queue Summary:")
print(f"  Configurations: {len(MAIN_CONFIGS)} (g_n sweep: 300, 500, 1000, 2000)")
print(f"  Seeds: {len(RANDOM_SEEDS)}")
print(f"  Total experiments: {total_experiments}")
print(f"  Estimated time: ~{total_experiments * 13.5 / 60:.1f} hours")
print("="*80)

print(f"\n🔬 FIRST 5 EXPERIMENTS:")
for i in range(min(5, len(experiment_queue))):
    exp_num, _, config, seed = experiment_queue[i]
    print(f"  {exp_num}. {config['name']}, seed={seed}")
# Out:
# ================================================================================
# ABLATION EXPERIMENT QUEUE - 20251116_125246
# ================================================================================
#
# Experiment Queue Summary:
#   Configurations: 4 (g_n sweep: 300, 500, 1000, 2000)
#   Seeds: 5
#   Total experiments: 20
#   Estimated time: ~4.5 hours
# ================================================================================
#
# 🔬 FIRST 5 EXPERIMENTS:
#   1. DNS-GA_g300_gen2, seed=7817
#   2. DNS-GA_g300_gen2, seed=52731
#   3. DNS-GA_g300_gen2, seed=51809
#   4. DNS-GA_g300_gen2, seed=35457
#   5. DNS-GA_g300_gen2, seed=47644

# %%
# STEP 4: Run All Experiments in Parallel with ipyparallel
print("\n" + "="*80)
print("RUNNING ALL EXPERIMENTS WITH ipyparallel")
print("="*80)
print(f"Start time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total experiments: {len(experiment_queue)}")
print(f"Setting up parallel cluster with 2 engines...")
print("="*80)

start_time_all = time.time()

import ipyparallel as ipp

# Start a local cluster with 2 engines
cluster = ipp.Cluster(n=2)
rc = cluster.start_and_connect_sync()

print(f"✓ Cluster started with {len(rc)} engines")
print(f"  Estimated time: ~{len(experiment_queue) / 2 * 3.3 / 60:.1f} hours")

# Push necessary imports to engines using execute (more reliable than sync_imports)
rc[:].execute("""
import jax
import jax.numpy as jnp
import functools
import time
import os
import json
from qdax.core.dns_ga import DominatedNoveltySearchGA
from qdax.core.dns import DominatedNoveltySearch
import qdax.tasks.brax as environments
from qdax.tasks.brax.env_creators import scoring_function_brax_envs as scoring_function
from qdax.core.neuroevolution.buffers.buffer import QDTransition
from qdax.core.neuroevolution.networks.networks import MLP
from qdax.core.emitters.mutation_operators import isoline_variation
from qdax.core.emitters.standard_emitters import MixingEmitter
from qdax.utils.metrics import CSVLogger, default_qd_metrics
""").wait()

# Push FIXED_PARAMS and helper functions to engines using .push()
rc[:].push({
    'FIXED_PARAMS': FIXED_PARAMS,
    'setup_environment': setup_environment,
    'create_scoring_function': create_scoring_function,
    'create_mutation_function': create_mutation_function,
    'calculate_ga_overhead_evals': calculate_ga_overhead_evals,
    'calculate_cumulative_evals_for_log': calculate_cumulative_evals_for_log,
    'interpolate_evals_to_milestone': interpolate_evals_to_milestone,
    'run_single_experiment': run_single_experiment
}).wait()

print("✓ Engines initialized with functions and parameters")

# Create load-balanced view
lview = rc.load_balanced_view()

# Define wrapper function for ipyparallel
def run_experiment_wrapper(exp_tuple):
    exp_num, total_exp, config, seed = exp_tuple
    try:
        result = run_single_experiment(config, seed, FIXED_PARAMS)
        result['exp_num'] = exp_num
        return ('success', result)
    except Exception as e:
        return ('error', {'config_name': config['name'], 'seed': seed, 'error': str(e)})

# Push wrapper to engines using .push()
rc[:].push({'run_experiment_wrapper': run_experiment_wrapper}).wait()

# Submit ALL experiments (including sanity check)
print("Submitting all experiments to cluster...")
async_results = []
for exp_tuple in experiment_queue:
    ar = lview.apply_async(run_experiment_wrapper, exp_tuple)
    async_results.append(ar)

print(f"✓ Submitted {len(async_results)} experiments")
print("\nMonitoring progress (updates every 10 seconds)...")
print("Note: Each experiment takes ~3-4 minutes")

# Monitor progress with non-blocking checks
all_results = []
errors = []
completed_count = 0
last_update = time.time()

while completed_count < len(async_results):
    # Check all results non-blocking
    for idx, ar in enumerate(async_results):
        if ar.ready() and not hasattr(ar, '_collected'):
            ar._collected = True  # Mark as collected
            status, result = ar.result()
            
            if status == 'success':
                all_results.append(result)
                config_name = result['config_name']
                seed = result['seed']
                qd = result['final_qd_score']
                print(f"  ✓ Completed: {config_name}, seed={seed}, QD={qd:.1f}")
            else:
                errors.append(result)
                print(f"  ✗ Failed: {result['config_name']}, seed={result['seed']}")
            
            completed_count += 1
    
    # Progress update every 10 seconds
    if time.time() - last_update > 10:
        elapsed = time.time() - start_time_all
        pct = completed_count / len(experiment_queue) * 100
        if completed_count > 0:
            avg_time = elapsed / completed_count
            remaining_time = (len(experiment_queue) - completed_count) * avg_time / 3600
            print(f"📊 Progress: {completed_count}/{len(experiment_queue)} ({pct:.1f}%) | Elapsed: {elapsed/60:.1f}m | Remaining: ~{remaining_time:.2f}h")
        else:
            print(f"📊 Waiting for first experiment to complete... ({elapsed:.0f}s elapsed)")
        last_update = time.time()
    
    time.sleep(2)  # Check every 2 seconds

# Cleanup
cluster.stop_cluster_sync()
print("\n✓ Cluster stopped")

total_time = time.time() - start_time_all

print("\n" + "="*80)
print("ALL EXPERIMENTS COMPLETE!")
print("="*80)
print(f"End time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Total time: {total_time / 60:.1f} minutes ({total_time / 3600:.2f} hours)")
print(f"Successful experiments: {len(all_results)}")
print(f"Failed experiments: {len(errors)}")

if errors:
    print("\nErrors encountered:")
    for error in errors:
        print(f"  • {error['config_name']}, seed={error['seed']}: {error['error']}")

# Save all results
results_file = f"ablation_logs/all_results_{timestamp}.json"
with open(results_file, 'w') as f:
    json.dump({
        'results': all_results,
        'errors': errors,
        'total_time': total_time,
        'timestamp': timestamp,
        'num_seeds': len(RANDOM_SEEDS),
        'seeds': RANDOM_SEEDS,
    }, f, indent=2)


print(f"\nResults saved to: {results_file}")
print("="*80)
# Out:
# ================================================================================
# RUNNING ALL EXPERIMENTS WITH ipyparallel
# ================================================================================
# Start time: 2025-11-16 09:21:22
# Total experiments: 20
# Setting up parallel cluster with 2 engines...
# ================================================================================
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
# Starting 2 engines with <class 'ipyparallel.cluster.launcher.LocalEngineSetLauncher'>
#   0%|          | 0/2 [00:00<?, ?engine/s]
# ✓ Cluster started with 2 engines
#   Estimated time: ~0.6 hours
# ✓ Engines initialized with functions and parameters
# Submitting all experiments to cluster...
# ✓ Submitted 20 experiments
#
# Monitoring progress (updates every 10 seconds)...
# Note: Each experiment takes ~3-4 minutes
# ✓ Engines initialized with functions and parameters
# Submitting all experiments to cluster...
# ✓ Submitted 20 experiments
#
# Monitoring progress (updates every 10 seconds)...
# Note: Each experiment takes ~3-4 minutes
# 📊 Waiting for first experiment to complete... (19s elapsed)
# 📊 Waiting for first experiment to complete... (19s elapsed)
# 📊 Waiting for first experiment to complete... (29s elapsed)
# 📊 Waiting for first experiment to complete... (29s elapsed)
# 📊 Waiting for first experiment to complete... (39s elapsed)
# 📊 Waiting for first experiment to complete... (39s elapsed)
# 📊 Waiting for first experiment to complete... (49s elapsed)
# 📊 Waiting for first experiment to complete... (49s elapsed)
# 📊 Waiting for first experiment to complete... (59s elapsed)
# 📊 Waiting for first experiment to complete... (59s elapsed)
# 📊 Waiting for first experiment to complete... (69s elapsed)
# 📊 Waiting for first experiment to complete... (69s elapsed)
# 📊 Waiting for first experiment to complete... (79s elapsed)
# 📊 Waiting for first experiment to complete... (79s elapsed)
# 📊 Waiting for first experiment to complete... (89s elapsed)
# 📊 Waiting for first experiment to complete... (89s elapsed)
# 📊 Waiting for first experiment to complete... (99s elapsed)
# 📊 Waiting for first experiment to complete... (99s elapsed)
# 📊 Waiting for first experiment to complete... (109s elapsed)
# 📊 Waiting for first experiment to complete... (109s elapsed)
# 📊 Waiting for first experiment to complete... (119s elapsed)
# 📊 Waiting for first experiment to complete... (119s elapsed)
# 📊 Waiting for first experiment to complete... (129s elapsed)
# 📊 Waiting for first experiment to complete... (129s elapsed)
# 📊 Waiting for first experiment to complete... (139s elapsed)
# 📊 Waiting for first experiment to complete... (139s elapsed)
# 📊 Waiting for first experiment to complete... (149s elapsed)
# 📊 Waiting for first experiment to complete... (149s elapsed)
# 📊 Waiting for first experiment to complete... (159s elapsed)
# 📊 Waiting for first experiment to complete... (159s elapsed)
# 📊 Waiting for first experiment to complete... (169s elapsed)
# 📊 Waiting for first experiment to complete... (169s elapsed)
# 📊 Waiting for first experiment to complete... (179s elapsed)
# 📊 Waiting for first experiment to complete... (179s elapsed)
# 📊 Waiting for first experiment to complete... (189s elapsed)
# 📊 Waiting for first experiment to complete... (189s elapsed)
# 📊 Waiting for first experiment to complete... (199s elapsed)
# 📊 Waiting for first experiment to complete... (199s elapsed)
# 📊 Waiting for first experiment to complete... (209s elapsed)
# 📊 Waiting for first experiment to complete... (209s elapsed)
# 📊 Waiting for first experiment to complete... (219s elapsed)
# 📊 Waiting for first experiment to complete... (219s elapsed)
# 📊 Waiting for first experiment to complete... (229s elapsed)
# 📊 Waiting for first experiment to complete... (229s elapsed)
# 📊 Waiting for first experiment to complete... (239s elapsed)
# 📊 Waiting for first experiment to complete... (239s elapsed)
# 📊 Waiting for first experiment to complete... (249s elapsed)
# 📊 Waiting for first experiment to complete... (249s elapsed)
# 📊 Waiting for first experiment to complete... (259s elapsed)
# 📊 Waiting for first experiment to complete... (259s elapsed)
# 📊 Waiting for first experiment to complete... (269s elapsed)
# 📊 Waiting for first experiment to complete... (269s elapsed)
# 📊 Waiting for first experiment to complete... (279s elapsed)
# 📊 Waiting for first experiment to complete... (279s elapsed)
# 📊 Waiting for first experiment to complete... (289s elapsed)
# 📊 Waiting for first experiment to complete... (289s elapsed)
# 📊 Waiting for first experiment to complete... (299s elapsed)
# 📊 Waiting for first experiment to complete... (299s elapsed)
# 📊 Waiting for first experiment to complete... (309s elapsed)
# 📊 Waiting for first experiment to complete... (309s elapsed)
# 📊 Waiting for first experiment to complete... (319s elapsed)
# 📊 Waiting for first experiment to complete... (319s elapsed)
# 📊 Waiting for first experiment to complete... (329s elapsed)
# 📊 Waiting for first experiment to complete... (329s elapsed)
# 📊 Waiting for first experiment to complete... (339s elapsed)
# 📊 Waiting for first experiment to complete... (339s elapsed)
# 📊 Waiting for first experiment to complete... (349s elapsed)
# 📊 Waiting for first experiment to complete... (349s elapsed)
# 📊 Waiting for first experiment to complete... (359s elapsed)
# 📊 Waiting for first experiment to complete... (359s elapsed)
# 📊 Waiting for first experiment to complete... (369s elapsed)
# 📊 Waiting for first experiment to complete... (369s elapsed)
# 📊 Waiting for first experiment to complete... (379s elapsed)
# 📊 Waiting for first experiment to complete... (379s elapsed)
# 📊 Waiting for first experiment to complete... (389s elapsed)
# 📊 Waiting for first experiment to complete... (389s elapsed)
# 📊 Waiting for first experiment to complete... (399s elapsed)
# 📊 Waiting for first experiment to complete... (399s elapsed)
# 📊 Waiting for first experiment to complete... (409s elapsed)
# 📊 Waiting for first experiment to complete... (409s elapsed)
# 📊 Waiting for first experiment to complete... (419s elapsed)
# 📊 Waiting for first experiment to complete... (419s elapsed)
# 📊 Waiting for first experiment to complete... (429s elapsed)
# 📊 Waiting for first experiment to complete... (429s elapsed)
# 📊 Waiting for first experiment to complete... (439s elapsed)
# 📊 Waiting for first experiment to complete... (439s elapsed)
# 📊 Waiting for first experiment to complete... (449s elapsed)
# 📊 Waiting for first experiment to complete... (449s elapsed)
# 📊 Waiting for first experiment to complete... (459s elapsed)
# 📊 Waiting for first experiment to complete... (459s elapsed)
# 📊 Waiting for first experiment to complete... (469s elapsed)
# 📊 Waiting for first experiment to complete... (469s elapsed)
# 📊 Waiting for first experiment to complete... (480s elapsed)
# 📊 Waiting for first experiment to complete... (480s elapsed)
# 📊 Waiting for first experiment to complete... (490s elapsed)
# 📊 Waiting for first experiment to complete... (490s elapsed)
# 📊 Waiting for first experiment to complete... (500s elapsed)
# 📊 Waiting for first experiment to complete... (500s elapsed)
#   ✓ Completed: DNS-GA_g300_gen2, seed=52731, QD=413818.9
# 📊 Progress: 1/20 (5.0%) | Elapsed: 8.5m | Remaining: ~2.69h
#   ✓ Completed: DNS-GA_g300_gen2, seed=52731, QD=413818.9
# 📊 Progress: 1/20 (5.0%) | Elapsed: 8.5m | Remaining: ~2.69h
#   ✓ Completed: DNS-GA_g300_gen2, seed=7817, QD=405441.6
#   ✓ Completed: DNS-GA_g300_gen2, seed=7817, QD=405441.6
# 📊 Progress: 2/20 (10.0%) | Elapsed: 8.7m | Remaining: ~1.30h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 8.7m | Remaining: ~1.30h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 8.8m | Remaining: ~1.32h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 8.8m | Remaining: ~1.32h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.0m | Remaining: ~1.35h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.0m | Remaining: ~1.35h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.2m | Remaining: ~1.37h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.2m | Remaining: ~1.37h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.3m | Remaining: ~1.40h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.3m | Remaining: ~1.40h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.5m | Remaining: ~1.42h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.5m | Remaining: ~1.42h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.7m | Remaining: ~1.45h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.7m | Remaining: ~1.45h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.8m | Remaining: ~1.47h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 9.8m | Remaining: ~1.47h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.0m | Remaining: ~1.50h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.0m | Remaining: ~1.50h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.2m | Remaining: ~1.52h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.2m | Remaining: ~1.52h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.3m | Remaining: ~1.55h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.3m | Remaining: ~1.55h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.5m | Remaining: ~1.57h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.5m | Remaining: ~1.57h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.7m | Remaining: ~1.60h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.7m | Remaining: ~1.60h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.8m | Remaining: ~1.62h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 10.8m | Remaining: ~1.62h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.0m | Remaining: ~1.65h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.0m | Remaining: ~1.65h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.2m | Remaining: ~1.67h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.2m | Remaining: ~1.67h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.3m | Remaining: ~1.70h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.3m | Remaining: ~1.70h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.5m | Remaining: ~1.72h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.5m | Remaining: ~1.72h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.7m | Remaining: ~1.75h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.7m | Remaining: ~1.75h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.8m | Remaining: ~1.78h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 11.8m | Remaining: ~1.78h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.0m | Remaining: ~1.80h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.0m | Remaining: ~1.80h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.2m | Remaining: ~1.83h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.2m | Remaining: ~1.83h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.3m | Remaining: ~1.85h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.3m | Remaining: ~1.85h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.5m | Remaining: ~1.88h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.5m | Remaining: ~1.88h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.7m | Remaining: ~1.90h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.7m | Remaining: ~1.90h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.8m | Remaining: ~1.93h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 12.8m | Remaining: ~1.93h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.0m | Remaining: ~1.95h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.0m | Remaining: ~1.95h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.2m | Remaining: ~1.98h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.2m | Remaining: ~1.98h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.3m | Remaining: ~2.00h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.3m | Remaining: ~2.00h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.5m | Remaining: ~2.03h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.5m | Remaining: ~2.03h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.7m | Remaining: ~2.05h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.7m | Remaining: ~2.05h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.8m | Remaining: ~2.08h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 13.8m | Remaining: ~2.08h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.0m | Remaining: ~2.10h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.0m | Remaining: ~2.10h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.2m | Remaining: ~2.13h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.2m | Remaining: ~2.13h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.3m | Remaining: ~2.15h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.3m | Remaining: ~2.15h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.5m | Remaining: ~2.18h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.5m | Remaining: ~2.18h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.7m | Remaining: ~2.20h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.7m | Remaining: ~2.20h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.8m | Remaining: ~2.23h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 14.8m | Remaining: ~2.23h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.0m | Remaining: ~2.25h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.0m | Remaining: ~2.25h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.2m | Remaining: ~2.28h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.2m | Remaining: ~2.28h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.3m | Remaining: ~2.30h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.3m | Remaining: ~2.30h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.5m | Remaining: ~2.33h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.5m | Remaining: ~2.33h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.7m | Remaining: ~2.35h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.7m | Remaining: ~2.35h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.8m | Remaining: ~2.38h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 15.8m | Remaining: ~2.38h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 16.0m | Remaining: ~2.40h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 16.0m | Remaining: ~2.40h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 16.2m | Remaining: ~2.43h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 16.2m | Remaining: ~2.43h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 16.3m | Remaining: ~2.45h
# 📊 Progress: 2/20 (10.0%) | Elapsed: 16.3m | Remaining: ~2.45h
#   ✓ Completed: DNS-GA_g300_gen2, seed=51809, QD=405344.8
#   ✓ Completed: DNS-GA_g300_gen2, seed=51809, QD=405344.8
#   ✓ Completed: DNS-GA_g300_gen2, seed=35457, QD=415163.8
#   ✓ Completed: DNS-GA_g300_gen2, seed=35457, QD=415163.8
# 📊 Progress: 4/20 (20.0%) | Elapsed: 16.5m | Remaining: ~1.10h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 16.5m | Remaining: ~1.10h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 16.7m | Remaining: ~1.11h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 16.7m | Remaining: ~1.11h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 16.8m | Remaining: ~1.12h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 16.8m | Remaining: ~1.12h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.0m | Remaining: ~1.13h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.0m | Remaining: ~1.13h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.2m | Remaining: ~1.15h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.2m | Remaining: ~1.15h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.4m | Remaining: ~1.16h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.4m | Remaining: ~1.16h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.5m | Remaining: ~1.17h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.5m | Remaining: ~1.17h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.7m | Remaining: ~1.18h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.7m | Remaining: ~1.18h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.9m | Remaining: ~1.19h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 17.9m | Remaining: ~1.19h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.0m | Remaining: ~1.20h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.0m | Remaining: ~1.20h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.2m | Remaining: ~1.21h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.2m | Remaining: ~1.21h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.4m | Remaining: ~1.22h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.4m | Remaining: ~1.22h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.5m | Remaining: ~1.23h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.5m | Remaining: ~1.23h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.7m | Remaining: ~1.25h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.7m | Remaining: ~1.25h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.9m | Remaining: ~1.26h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 18.9m | Remaining: ~1.26h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.0m | Remaining: ~1.27h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.0m | Remaining: ~1.27h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.2m | Remaining: ~1.28h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.2m | Remaining: ~1.28h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.4m | Remaining: ~1.29h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.4m | Remaining: ~1.29h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.5m | Remaining: ~1.30h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.5m | Remaining: ~1.30h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.7m | Remaining: ~1.31h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.7m | Remaining: ~1.31h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.9m | Remaining: ~1.32h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 19.9m | Remaining: ~1.32h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.0m | Remaining: ~1.34h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.0m | Remaining: ~1.34h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.2m | Remaining: ~1.35h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.2m | Remaining: ~1.35h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.4m | Remaining: ~1.36h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.4m | Remaining: ~1.36h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.5m | Remaining: ~1.37h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.5m | Remaining: ~1.37h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.7m | Remaining: ~1.38h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.7m | Remaining: ~1.38h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.9m | Remaining: ~1.39h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 20.9m | Remaining: ~1.39h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.0m | Remaining: ~1.40h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.0m | Remaining: ~1.40h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.2m | Remaining: ~1.41h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.2m | Remaining: ~1.41h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.4m | Remaining: ~1.42h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.4m | Remaining: ~1.42h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.5m | Remaining: ~1.44h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.5m | Remaining: ~1.44h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.7m | Remaining: ~1.45h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.7m | Remaining: ~1.45h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.9m | Remaining: ~1.46h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 21.9m | Remaining: ~1.46h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.0m | Remaining: ~1.47h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.0m | Remaining: ~1.47h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.2m | Remaining: ~1.48h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.2m | Remaining: ~1.48h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.4m | Remaining: ~1.49h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.4m | Remaining: ~1.49h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.5m | Remaining: ~1.50h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.5m | Remaining: ~1.50h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.7m | Remaining: ~1.51h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.7m | Remaining: ~1.51h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.9m | Remaining: ~1.52h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 22.9m | Remaining: ~1.52h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.0m | Remaining: ~1.54h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.0m | Remaining: ~1.54h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.2m | Remaining: ~1.55h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.2m | Remaining: ~1.55h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.4m | Remaining: ~1.56h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.4m | Remaining: ~1.56h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.5m | Remaining: ~1.57h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.5m | Remaining: ~1.57h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.7m | Remaining: ~1.58h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.7m | Remaining: ~1.58h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.9m | Remaining: ~1.59h
# 📊 Progress: 4/20 (20.0%) | Elapsed: 23.9m | Remaining: ~1.59h
#   ✓ Completed: DNS-GA_g500_gen2, seed=7817, QD=408418.1
#   ✓ Completed: DNS-GA_g500_gen2, seed=7817, QD=408418.1
# 📊 Progress: 5/20 (25.0%) | Elapsed: 24.0m | Remaining: ~1.20h
# 📊 Progress: 5/20 (25.0%) | Elapsed: 24.0m | Remaining: ~1.20h
# 📊 Progress: 5/20 (25.0%) | Elapsed: 24.2m | Remaining: ~1.21h
# 📊 Progress: 5/20 (25.0%) | Elapsed: 24.2m | Remaining: ~1.21h
#   ✓ Completed: DNS-GA_g300_gen2, seed=47644, QD=411779.4
#   ✓ Completed: DNS-GA_g300_gen2, seed=47644, QD=411779.4
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.4m | Remaining: ~0.95h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.4m | Remaining: ~0.95h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.5m | Remaining: ~0.95h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.5m | Remaining: ~0.95h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.7m | Remaining: ~0.96h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.7m | Remaining: ~0.96h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.9m | Remaining: ~0.97h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 24.9m | Remaining: ~0.97h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.0m | Remaining: ~0.97h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.0m | Remaining: ~0.97h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.2m | Remaining: ~0.98h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.2m | Remaining: ~0.98h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.4m | Remaining: ~0.99h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.4m | Remaining: ~0.99h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.6m | Remaining: ~0.99h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.6m | Remaining: ~0.99h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.7m | Remaining: ~1.00h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.7m | Remaining: ~1.00h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.9m | Remaining: ~1.01h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 25.9m | Remaining: ~1.01h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.1m | Remaining: ~1.01h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.1m | Remaining: ~1.01h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.2m | Remaining: ~1.02h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.2m | Remaining: ~1.02h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.4m | Remaining: ~1.03h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.4m | Remaining: ~1.03h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.6m | Remaining: ~1.03h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.6m | Remaining: ~1.03h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.7m | Remaining: ~1.04h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.7m | Remaining: ~1.04h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.9m | Remaining: ~1.05h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 26.9m | Remaining: ~1.05h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.1m | Remaining: ~1.05h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.1m | Remaining: ~1.05h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.2m | Remaining: ~1.06h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.2m | Remaining: ~1.06h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.4m | Remaining: ~1.07h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.4m | Remaining: ~1.07h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.6m | Remaining: ~1.07h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.6m | Remaining: ~1.07h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.7m | Remaining: ~1.08h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.7m | Remaining: ~1.08h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.9m | Remaining: ~1.08h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 27.9m | Remaining: ~1.08h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.1m | Remaining: ~1.09h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.1m | Remaining: ~1.09h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.2m | Remaining: ~1.10h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.2m | Remaining: ~1.10h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.4m | Remaining: ~1.10h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.4m | Remaining: ~1.10h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.6m | Remaining: ~1.11h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.6m | Remaining: ~1.11h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.7m | Remaining: ~1.12h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.7m | Remaining: ~1.12h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.9m | Remaining: ~1.12h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 28.9m | Remaining: ~1.12h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.1m | Remaining: ~1.13h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.1m | Remaining: ~1.13h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.2m | Remaining: ~1.14h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.2m | Remaining: ~1.14h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.4m | Remaining: ~1.14h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.4m | Remaining: ~1.14h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.6m | Remaining: ~1.15h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.6m | Remaining: ~1.15h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.7m | Remaining: ~1.16h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.7m | Remaining: ~1.16h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.9m | Remaining: ~1.16h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 29.9m | Remaining: ~1.16h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.1m | Remaining: ~1.17h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.1m | Remaining: ~1.17h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.2m | Remaining: ~1.18h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.2m | Remaining: ~1.18h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.4m | Remaining: ~1.18h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.4m | Remaining: ~1.18h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.6m | Remaining: ~1.19h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.6m | Remaining: ~1.19h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.7m | Remaining: ~1.20h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.7m | Remaining: ~1.20h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.9m | Remaining: ~1.20h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 30.9m | Remaining: ~1.20h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 31.1m | Remaining: ~1.21h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 31.1m | Remaining: ~1.21h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 31.2m | Remaining: ~1.21h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 31.2m | Remaining: ~1.21h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 31.4m | Remaining: ~1.22h
# 📊 Progress: 6/20 (30.0%) | Elapsed: 31.4m | Remaining: ~1.22h
#   ✓ Completed: DNS-GA_g500_gen2, seed=52731, QD=420563.5
#   ✓ Completed: DNS-GA_g500_gen2, seed=52731, QD=420563.5
# 📊 Progress: 7/20 (35.0%) | Elapsed: 31.6m | Remaining: ~0.98h
# 📊 Progress: 7/20 (35.0%) | Elapsed: 31.6m | Remaining: ~0.98h
#   ✓ Completed: DNS-GA_g500_gen2, seed=51809, QD=402988.8
#   ✓ Completed: DNS-GA_g500_gen2, seed=51809, QD=402988.8
# 📊 Progress: 8/20 (40.0%) | Elapsed: 31.7m | Remaining: ~0.79h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 31.7m | Remaining: ~0.79h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 31.9m | Remaining: ~0.80h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 31.9m | Remaining: ~0.80h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.1m | Remaining: ~0.80h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.1m | Remaining: ~0.80h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.2m | Remaining: ~0.81h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.2m | Remaining: ~0.81h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.4m | Remaining: ~0.81h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.4m | Remaining: ~0.81h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.6m | Remaining: ~0.81h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.6m | Remaining: ~0.81h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.7m | Remaining: ~0.82h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.7m | Remaining: ~0.82h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.9m | Remaining: ~0.82h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 32.9m | Remaining: ~0.82h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.1m | Remaining: ~0.83h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.1m | Remaining: ~0.83h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.3m | Remaining: ~0.83h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.3m | Remaining: ~0.83h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.4m | Remaining: ~0.84h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.4m | Remaining: ~0.84h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.6m | Remaining: ~0.84h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.6m | Remaining: ~0.84h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.8m | Remaining: ~0.84h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.8m | Remaining: ~0.84h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.9m | Remaining: ~0.85h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 33.9m | Remaining: ~0.85h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.1m | Remaining: ~0.85h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.1m | Remaining: ~0.85h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.3m | Remaining: ~0.86h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.3m | Remaining: ~0.86h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.4m | Remaining: ~0.86h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.4m | Remaining: ~0.86h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.6m | Remaining: ~0.86h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.6m | Remaining: ~0.86h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.8m | Remaining: ~0.87h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.8m | Remaining: ~0.87h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.9m | Remaining: ~0.87h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 34.9m | Remaining: ~0.87h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.1m | Remaining: ~0.88h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.1m | Remaining: ~0.88h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.3m | Remaining: ~0.88h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.3m | Remaining: ~0.88h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.4m | Remaining: ~0.89h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.4m | Remaining: ~0.89h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.6m | Remaining: ~0.89h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.6m | Remaining: ~0.89h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.8m | Remaining: ~0.89h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.8m | Remaining: ~0.89h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.9m | Remaining: ~0.90h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 35.9m | Remaining: ~0.90h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.1m | Remaining: ~0.90h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.1m | Remaining: ~0.90h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.3m | Remaining: ~0.91h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.3m | Remaining: ~0.91h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.4m | Remaining: ~0.91h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.4m | Remaining: ~0.91h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.6m | Remaining: ~0.91h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.6m | Remaining: ~0.91h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.8m | Remaining: ~0.92h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.8m | Remaining: ~0.92h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.9m | Remaining: ~0.92h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 36.9m | Remaining: ~0.92h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.1m | Remaining: ~0.93h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.1m | Remaining: ~0.93h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.3m | Remaining: ~0.93h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.3m | Remaining: ~0.93h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.4m | Remaining: ~0.94h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.4m | Remaining: ~0.94h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.6m | Remaining: ~0.94h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.6m | Remaining: ~0.94h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.8m | Remaining: ~0.94h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.8m | Remaining: ~0.94h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.9m | Remaining: ~0.95h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 37.9m | Remaining: ~0.95h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.1m | Remaining: ~0.95h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.1m | Remaining: ~0.95h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.3m | Remaining: ~0.96h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.3m | Remaining: ~0.96h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.4m | Remaining: ~0.96h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.4m | Remaining: ~0.96h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.6m | Remaining: ~0.97h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.6m | Remaining: ~0.97h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.8m | Remaining: ~0.97h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.8m | Remaining: ~0.97h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.9m | Remaining: ~0.97h
# 📊 Progress: 8/20 (40.0%) | Elapsed: 38.9m | Remaining: ~0.97h
#   ✓ Completed: DNS-GA_g500_gen2, seed=35457, QD=410620.5
#   ✓ Completed: DNS-GA_g500_gen2, seed=35457, QD=410620.5
# 📊 Progress: 9/20 (45.0%) | Elapsed: 39.1m | Remaining: ~0.80h
# 📊 Progress: 9/20 (45.0%) | Elapsed: 39.1m | Remaining: ~0.80h
#   ✓ Completed: DNS-GA_g500_gen2, seed=47644, QD=417984.2
#   ✓ Completed: DNS-GA_g500_gen2, seed=47644, QD=417984.2
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.3m | Remaining: ~0.65h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.3m | Remaining: ~0.65h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.4m | Remaining: ~0.66h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.4m | Remaining: ~0.66h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.6m | Remaining: ~0.66h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.6m | Remaining: ~0.66h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.8m | Remaining: ~0.66h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.8m | Remaining: ~0.66h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.9m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 39.9m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.1m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.1m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.3m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.3m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.4m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.4m | Remaining: ~0.67h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.6m | Remaining: ~0.68h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.6m | Remaining: ~0.68h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.8m | Remaining: ~0.68h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.8m | Remaining: ~0.68h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.9m | Remaining: ~0.68h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 40.9m | Remaining: ~0.68h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.1m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.1m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.3m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.3m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.4m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.4m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.6m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.6m | Remaining: ~0.69h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.8m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.8m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.9m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 41.9m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.1m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.1m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.3m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.3m | Remaining: ~0.70h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.4m | Remaining: ~0.71h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.4m | Remaining: ~0.71h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.6m | Remaining: ~0.71h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.6m | Remaining: ~0.71h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.8m | Remaining: ~0.71h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.8m | Remaining: ~0.71h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.9m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 42.9m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.1m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.1m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.3m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.3m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.4m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.4m | Remaining: ~0.72h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.6m | Remaining: ~0.73h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.6m | Remaining: ~0.73h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.8m | Remaining: ~0.73h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.8m | Remaining: ~0.73h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.9m | Remaining: ~0.73h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 43.9m | Remaining: ~0.73h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.1m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.1m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.3m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.3m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.5m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.5m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.6m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.6m | Remaining: ~0.74h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.8m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 44.8m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.0m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.0m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.1m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.1m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.3m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.3m | Remaining: ~0.75h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.5m | Remaining: ~0.76h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.5m | Remaining: ~0.76h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.6m | Remaining: ~0.76h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.6m | Remaining: ~0.76h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.8m | Remaining: ~0.76h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 45.8m | Remaining: ~0.76h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.0m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.0m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.1m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.1m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.3m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.3m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.5m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.5m | Remaining: ~0.77h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.6m | Remaining: ~0.78h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.6m | Remaining: ~0.78h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.8m | Remaining: ~0.78h
# 📊 Progress: 10/20 (50.0%) | Elapsed: 46.8m | Remaining: ~0.78h
#   ✓ Completed: DNS-GA_g1000_gen2, seed=7817, QD=408221.9
#   ✓ Completed: DNS-GA_g1000_gen2, seed=7817, QD=408221.9
# 📊 Progress: 11/20 (55.0%) | Elapsed: 47.0m | Remaining: ~0.64h
# 📊 Progress: 11/20 (55.0%) | Elapsed: 47.0m | Remaining: ~0.64h
#   ✓ Completed: DNS-GA_g1000_gen2, seed=52731, QD=413515.8
#   ✓ Completed: DNS-GA_g1000_gen2, seed=52731, QD=413515.8
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.1m | Remaining: ~0.52h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.1m | Remaining: ~0.52h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.3m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.3m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.5m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.5m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.6m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.6m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.8m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 47.8m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.0m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.0m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.1m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.1m | Remaining: ~0.53h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.3m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.3m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.5m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.5m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.6m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.6m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.8m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 48.8m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.0m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.0m | Remaining: ~0.54h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.1m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.1m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.3m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.3m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.5m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.5m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.6m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.6m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.8m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 49.8m | Remaining: ~0.55h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.0m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.0m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.1m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.1m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.3m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.3m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.5m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.5m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.6m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.6m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.8m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 50.8m | Remaining: ~0.56h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.0m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.0m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.1m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.1m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.3m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.3m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.5m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.5m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.6m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.6m | Remaining: ~0.57h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.8m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 51.8m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.0m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.0m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.1m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.1m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.3m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.3m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.5m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.5m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.6m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.6m | Remaining: ~0.58h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.8m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 52.8m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.0m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.0m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.1m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.1m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.3m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.3m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.5m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.5m | Remaining: ~0.59h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.6m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.6m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.8m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 53.8m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.0m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.0m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.1m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.1m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.3m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.3m | Remaining: ~0.60h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.5m | Remaining: ~0.61h
# 📊 Progress: 12/20 (60.0%) | Elapsed: 54.5m | Remaining: ~0.61h
#   ✓ Completed: DNS-GA_g1000_gen2, seed=51809, QD=407024.8
#   ✓ Completed: DNS-GA_g1000_gen2, seed=51809, QD=407024.8
# 📊 Progress: 13/20 (65.0%) | Elapsed: 54.6m | Remaining: ~0.49h
# 📊 Progress: 13/20 (65.0%) | Elapsed: 54.6m | Remaining: ~0.49h
#   ✓ Completed: DNS-GA_g1000_gen2, seed=35457, QD=406016.9
#   ✓ Completed: DNS-GA_g1000_gen2, seed=35457, QD=406016.9
# 📊 Progress: 14/20 (70.0%) | Elapsed: 54.8m | Remaining: ~0.39h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 54.8m | Remaining: ~0.39h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.0m | Remaining: ~0.39h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.0m | Remaining: ~0.39h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.1m | Remaining: ~0.39h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.1m | Remaining: ~0.39h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.3m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.3m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.5m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.5m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.6m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.6m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.8m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 55.8m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.0m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.0m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.2m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.2m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.3m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.3m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.5m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.5m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.7m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.7m | Remaining: ~0.40h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.8m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 56.8m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.0m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.0m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.2m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.2m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.3m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.3m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.5m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.5m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.7m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.7m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.8m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 57.8m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.0m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.0m | Remaining: ~0.41h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.2m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.2m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.3m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.3m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.5m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.5m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.7m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.7m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.8m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 58.8m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.0m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.0m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.2m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.2m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.3m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.3m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.5m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.5m | Remaining: ~0.42h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.7m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.7m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.8m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 59.8m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.0m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.0m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.2m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.2m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.3m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.3m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.5m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.5m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.7m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.7m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.8m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 60.8m | Remaining: ~0.43h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 61.0m | Remaining: ~0.44h
# 📊 Progress: 14/20 (70.0%) | Elapsed: 61.0m | Remaining: ~0.44h
# ...
# 2025-11-16 09:21:24.212 [IPEngine.0] Connecting shell to tcp://127.0.0.1:60867
# 2025-11-16 09:21:24.212 [IPEngine.0] Connecting shell to tcp://127.0.0.1:60871
# 2025-11-16 09:21:24.212 [IPEngine.0] Starting nanny
# 2025-11-16 09:21:24.435 [KernelNanny.0] Starting kernel nanny for engine 0, pid=18380, nanny pid=18383
# 2025-11-16 09:21:24.435 [KernelNanny.0] Nanny watching parent pid 18380.
# 2025-11-16 09:21:24.500 [IPEngine.0] Loading IPython extension: storemagic
# 2025-11-16 09:21:24.501 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-16 09:21:24.502 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-16 09:21:24.502 [IPEngine.0] Completed registration with id 0
# 2025-11-16 09:21:29.830 [IPEngine.0] Handling execute_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_1
# 2025-11-16 09:21:31.421 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_3
# 2025-11-16 09:21:31.426 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_5
# 2025-11-16 09:21:31.433 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_8
# 2025-11-16 09:29:51.230 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_9
# 2025-11-16 09:37:46.850 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_11
# 2025-11-16 09:45:35.904 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_14
# 2025-11-16 09:53:01.310 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_16
# 2025-11-16 10:00:33.616 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_18
# 2025-11-16 10:08:21.517 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_20
# 2025-11-16 10:16:02.278 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_22
# 2025-11-16 10:23:35.035 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_23
# 2025-11-16 10:31:03.779 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_25
# 2025-11-16 10:38:39.057 [IPEngine.0] CRITICAL | received signal 15, stopping
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/__main__.py", line 4, in <module>
#     main()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/app.py", line 992, in start
#     self.loop.run_sync(self._start)
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 546, in run_sync
#     raise RuntimeError("Event loop stopped before Future completed.")
# RuntimeError: Event loop stopped before Future completed.
# 2025-11-16 10:38:41.792 [KernelNanny.0] Pipe closed, parent 18380 has status: zombie
# 2025-11-16 10:38:41.793 [KernelNanny.0] Notifying Hub that our parent has shut down
# 2025-11-16 10:38:41.828 [KernelNanny.0] Parent 18380 exited with status None.
#
# Output for 1:
# 2025-11-16 09:21:24.309 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-11-16 09:21:24.309 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-11-16 09:21:24.310 [IPEngine] Registering with controller at tcp://127.0.0.1:60864
# 2025-11-16 09:21:24.312 [IPEngine.1] Shell_addrs: ['tcp://127.0.0.1:60866', 'tcp://127.0.0.1:60867', 'tcp://127.0.0.1:60872']
# 2025-11-16 09:21:24.312 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60866
# 2025-11-16 09:21:24.312 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60867
# 2025-11-16 09:21:24.313 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60872
# 2025-11-16 09:21:24.313 [IPEngine.1] Starting nanny
# 2025-11-16 09:21:24.531 [KernelNanny.1] Starting kernel nanny for engine 1, pid=18381, nanny pid=18384
# 2025-11-16 09:21:24.532 [KernelNanny.1] Nanny watching parent pid 18381.
# 2025-11-16 09:21:24.572 [IPEngine.1] Loading IPython extension: storemagic
# 2025-11-16 09:21:24.573 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-16 09:21:24.574 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-16 09:21:24.574 [IPEngine.1] Completed registration with id 1
# 2025-11-16 09:21:29.830 [IPEngine.1] Handling execute_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_2
# 2025-11-16 09:21:31.422 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_4
# 2025-11-16 09:21:31.426 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_6
# 2025-11-16 09:21:31.432 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_7
# 2025-11-16 09:29:52.977 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_10
# 2025-11-16 09:37:50.712 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_12
# 2025-11-16 09:45:23.502 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_13
# 2025-11-16 09:52:49.533 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_15
# 2025-11-16 10:00:24.328 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_17
# 2025-11-16 10:08:15.952 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_19
# 2025-11-16 10:15:58.323 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_21
# 2025-11-16 10:23:42.067 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_24
# 2025-11-16 10:31:13.402 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_26
# 2025-11-16 10:38:41.809 [IPEngine.1] CRITICAL | received signal 15, stopping
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/__main__.py", line 4, in <module>
#     main()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/app.py", line 992, in start
#     self.loop.run_sync(self._start)
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 546, in run_sync
#     raise RuntimeError("Event loop stopped before Future completed.")
# RuntimeError: Event loop stopped before Future completed.
# 2025-11-16 10:38:44.400 [KernelNanny.1] Pipe closed, parent 18381 has status: zombie
# 2025-11-16 10:38:44.402 [KernelNanny.1] Notifying Hub that our parent has shut down
#
# engine set stopped 1763306483: {'engines': {'0': {'exit_code': 1, 'pid': 18380, 'identifier': '0'}, '1': {'exit_code': 1, 'pid': 18381, 'identifier': '1'}}, 'exit_code': 1}
#
# ✓ Cluster stopped
#
# ================================================================================
# ALL EXPERIMENTS COMPLETE!
# ================================================================================
# End time: 2025-11-16 10:38:44
# Total time: 77.4 minutes (1.29 hours)
# Successful experiments: 20
# Failed experiments: 0
#
# Results saved to: ablation_logs/all_results_20251116_092121.json
# ================================================================================
# Output for 0:
# 2025-11-16 09:21:24.209 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-11-16 09:21:24.210 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-11-16 09:21:24.211 [IPEngine] Registering with controller at tcp://127.0.0.1:60864
# 2025-11-16 09:21:24.212 [IPEngine.0] Shell_addrs: ['tcp://127.0.0.1:60866', 'tcp://127.0.0.1:60867', 'tcp://127.0.0.1:60871']
# 2025-11-16 09:21:24.212 [IPEngine.0] Connecting shell to tcp://127.0.0.1:60866
# 2025-11-16 09:21:24.212 [IPEngine.0] Connecting shell to tcp://127.0.0.1:60867
# 2025-11-16 09:21:24.212 [IPEngine.0] Connecting shell to tcp://127.0.0.1:60871
# 2025-11-16 09:21:24.212 [IPEngine.0] Starting nanny
# 2025-11-16 09:21:24.435 [KernelNanny.0] Starting kernel nanny for engine 0, pid=18380, nanny pid=18383
# 2025-11-16 09:21:24.435 [KernelNanny.0] Nanny watching parent pid 18380.
# 2025-11-16 09:21:24.500 [IPEngine.0] Loading IPython extension: storemagic
# 2025-11-16 09:21:24.501 [IPEngine.0] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-16 09:21:24.502 [IPEngine.0] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-16 09:21:24.502 [IPEngine.0] Completed registration with id 0
# 2025-11-16 09:21:29.830 [IPEngine.0] Handling execute_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_1
# 2025-11-16 09:21:31.421 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_3
# 2025-11-16 09:21:31.426 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_5
# 2025-11-16 09:21:31.433 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_8
# 2025-11-16 09:29:51.230 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_9
# 2025-11-16 09:37:46.850 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_11
# 2025-11-16 09:45:35.904 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_14
# 2025-11-16 09:53:01.310 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_16
# 2025-11-16 10:00:33.616 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_18
# 2025-11-16 10:08:21.517 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_20
# 2025-11-16 10:16:02.278 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_22
# 2025-11-16 10:23:35.035 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_23
# 2025-11-16 10:31:03.779 [IPEngine.0] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_25
# 2025-11-16 10:38:39.057 [IPEngine.0] CRITICAL | received signal 15, stopping
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/__main__.py", line 4, in <module>
#     main()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/app.py", line 992, in start
#     self.loop.run_sync(self._start)
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 546, in run_sync
#     raise RuntimeError("Event loop stopped before Future completed.")
# RuntimeError: Event loop stopped before Future completed.
# 2025-11-16 10:38:41.792 [KernelNanny.0] Pipe closed, parent 18380 has status: zombie
# 2025-11-16 10:38:41.793 [KernelNanny.0] Notifying Hub that our parent has shut down
# 2025-11-16 10:38:41.828 [KernelNanny.0] Parent 18380 exited with status None.
#
# Output for 1:
# 2025-11-16 09:21:24.309 [IPEngine] Loading connection info from $IPP_CONNECTION_INFO
# 2025-11-16 09:21:24.309 [IPEngine] WARNING | Not using CurveZMQ security
# 2025-11-16 09:21:24.310 [IPEngine] Registering with controller at tcp://127.0.0.1:60864
# 2025-11-16 09:21:24.312 [IPEngine.1] Shell_addrs: ['tcp://127.0.0.1:60866', 'tcp://127.0.0.1:60867', 'tcp://127.0.0.1:60872']
# 2025-11-16 09:21:24.312 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60866
# 2025-11-16 09:21:24.312 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60867
# 2025-11-16 09:21:24.313 [IPEngine.1] Connecting shell to tcp://127.0.0.1:60872
# 2025-11-16 09:21:24.313 [IPEngine.1] Starting nanny
# 2025-11-16 09:21:24.531 [KernelNanny.1] Starting kernel nanny for engine 1, pid=18381, nanny pid=18384
# 2025-11-16 09:21:24.532 [KernelNanny.1] Nanny watching parent pid 18381.
# 2025-11-16 09:21:24.572 [IPEngine.1] Loading IPython extension: storemagic
# 2025-11-16 09:21:24.573 [IPEngine.1] WARNING | debugpy_stream undefined, debugging will not be enabled
# 2025-11-16 09:21:24.574 [IPEngine.1] Starting to monitor the heartbeat signal from the hub every 3500 ms.
# 2025-11-16 09:21:24.574 [IPEngine.1] Completed registration with id 1
# 2025-11-16 09:21:29.830 [IPEngine.1] Handling execute_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_2
# 2025-11-16 09:21:31.422 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_4
# 2025-11-16 09:21:31.426 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_6
# 2025-11-16 09:21:31.432 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_7
# 2025-11-16 09:29:52.977 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_10
# 2025-11-16 09:37:50.712 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_12
# 2025-11-16 09:45:23.502 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_13
# 2025-11-16 09:52:49.533 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_15
# 2025-11-16 10:00:24.328 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_17
# 2025-11-16 10:08:15.952 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_19
# 2025-11-16 10:15:58.323 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_21
# 2025-11-16 10:23:42.067 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_24
# 2025-11-16 10:31:13.402 [IPEngine.1] Handling apply_request: f190bc2c-4937cdfc7cf4691497f7cf05_18366_26
# 2025-11-16 10:38:41.809 [IPEngine.1] CRITICAL | received signal 15, stopping
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/__main__.py", line 4, in <module>
#     main()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/ipyparallel/engine/app.py", line 992, in start
#     self.loop.run_sync(self._start)
#   File "/Users/briancf/Desktop/source/EvoAlgsAndSwarm/lib-qdax/QDax/.venv/lib/python3.12/site-packages/tornado/ioloop.py", line 546, in run_sync
#     raise RuntimeError("Event loop stopped before Future completed.")
# RuntimeError: Event loop stopped before Future completed.
# 2025-11-16 10:38:44.400 [KernelNanny.1] Pipe closed, parent 18381 has status: zombie
# 2025-11-16 10:38:44.402 [KernelNanny.1] Notifying Hub that our parent has shut down
#
# engine set stopped 1763306483: {'engines': {'0': {'exit_code': 1, 'pid': 18380, 'identifier': '0'}, '1': {'exit_code': 1, 'pid': 18381, 'identifier': '1'}}, 'exit_code': 1}
#
# ✓ Cluster stopped
#
# ================================================================================
# ALL EXPERIMENTS COMPLETE!
# ================================================================================
# End time: 2025-11-16 10:38:44
# Total time: 77.4 minutes (1.29 hours)
# Successful experiments: 20
# Failed experiments: 0
#
# Results saved to: ablation_logs/all_results_20251116_092121.json
# ================================================================================

# %% [markdown]
# ## STEP 5: Load Results and Analyze Performance

# %%
import glob
import json
import pandas as pd

# Load results from JSON file
log_dir = "ablation_logs"
results_files = glob.glob(f"{log_dir}/all_results_*.json")
results_file = sorted(results_files)[-1]

print(f"Loading results from: {results_file}")

with open(results_file, 'r') as f:
    data = json.load(f)
    all_results = data['results']

# Create DataFrame
df = pd.DataFrame(all_results)

print(f"\nLoaded {len(df)} experiment results")
print(f"Configurations: {df['config_name'].unique()}")
print(f"Seeds per config: {df.groupby('config_name').size().to_dict()}")
# Out:
# Loading results from: ablation_logs/all_results_20251116_092121.json
#
# Loaded 20 experiment results
# Configurations: ['DNS-GA_g300_gen2' 'DNS-GA_g500_gen2' 'DNS-GA_g1000_gen2'
#  'DNS-GA_g2000_gen2']
# Seeds per config: {'DNS-GA_g1000_gen2': 5, 'DNS-GA_g2000_gen2': 5, 'DNS-GA_g300_gen2': 5, 'DNS-GA_g500_gen2': 5}

# %% [markdown]
# ### Performance Summary: QD Score and Max Fitness

# %%
print("="*80)
print("ABLATION STUDY: PERFORMANCE SUMMARY")
print("="*80)
print(f"\nEnvironment: {FIXED_PARAMS['env_name']}")
print(f"Iterations: {FIXED_PARAMS['num_iterations']}")
print(f"Seeds: {len(RANDOM_SEEDS)}")
print("="*80)

# Summary statistics
print("\nFinal Performance by Configuration:")
print("="*80)

for config in MAIN_CONFIGS:
    config_df = df[df['config_name'] == config['name']]
    ga_calls = FIXED_PARAMS['num_iterations'] // config['g_n']
    
    print(f"\n{config['name']} ({ga_calls} GA calls):")
    print(f"  QD Score:    {config_df['final_qd_score'].mean():>10,.1f} ± {config_df['final_qd_score'].std():>6.1f}")
    print(f"  Max Fitness: {config_df['final_max_fitness'].mean():>10.3f} ± {config_df['final_max_fitness'].std():>6.3f}")
    print(f"  Coverage:    {config_df['final_coverage'].mean():>10.2f}% ± {config_df['final_coverage'].std():>5.2f}%")

print("\n" + "="*80)
# Out:
# ================================================================================
# ABLATION STUDY: PERFORMANCE SUMMARY
# ================================================================================
#
# Environment: walker2d_uni
# Iterations: 3000
# Seeds: 5
# ================================================================================
#
# Final Performance by Configuration:
# ================================================================================
#
# DNS-GA_g300_gen2 (10 GA calls):
#   QD Score:     410,309.7 ± 4647.2
#   Max Fitness:    319.333 ± 14.826
#   Coverage:        100.00% ±  0.00%
#
# DNS-GA_g500_gen2 (6 GA calls):
#   QD Score:     412,115.0 ± 7159.2
#   Max Fitness:    320.008 ± 13.333
#   Coverage:        100.00% ±  0.00%
#
# DNS-GA_g1000_gen2 (3 GA calls):
#   QD Score:     410,592.4 ± 5134.2
#   Max Fitness:    319.970 ± 13.302
#   Coverage:        100.00% ±  0.00%
#
# DNS-GA_g2000_gen2 (1 GA calls):
#   QD Score:     412,361.1 ± 3371.4
#   Max Fitness:    319.908 ± 15.680
#   Coverage:        100.00% ±  0.00%
#
# ================================================================================

# %% [markdown]
# ### Statistical Comparisons: Pairwise T-Tests

# %%
print("="*80)
print("PAIRWISE COMPARISONS: DNS-GA SCHEDULES")
print("="*80)
print("\nComparing different g_n values to understand GA frequency impact")
print("="*80)

# Compare each config pair
configs = MAIN_CONFIGS
for i in range(len(configs)):
    for j in range(i+1, len(configs)):
        config1 = configs[i]
        config2 = configs[j]
        
        config1_df = df[df['config_name'] == config1['name']]
        config2_df = df[df['config_name'] == config2['name']]
        
        ga_calls1 = FIXED_PARAMS['num_iterations'] // config1['g_n']
        ga_calls2 = FIXED_PARAMS['num_iterations'] // config2['g_n']
        
        print(f"\n{config1['name']} ({ga_calls1} calls) vs {config2['name']} ({ga_calls2} calls):")
        print(f"  Sample sizes: n={len(config1_df)} vs n={len(config2_df)}")
        print("  " + "=" * 70)
        
        # QD Score comparison
        t_stat_qd, p_val_qd = stats.ttest_ind(
            config1_df['final_qd_score'].values,
            config2_df['final_qd_score'].values
        )
        
        qd_diff = config1_df['final_qd_score'].mean() - config2_df['final_qd_score'].mean()
        qd_pct = (qd_diff / config2_df['final_qd_score'].mean()) * 100
        
        print(f"\n  QD Score:")
        print(f"    {config1['name']}: {config1_df['final_qd_score'].mean():>10,.1f}")
        print(f"    {config2['name']}: {config2_df['final_qd_score'].mean():>10,.1f}")
        print(f"    Difference: {qd_diff:>+10,.1f} ({qd_pct:>+6.2f}%)")
        print(f"    t={t_stat_qd:.3f}, p={p_val_qd:.4f}", end="")
        
        if p_val_qd < 0.001:
            print(" *** (highly significant)")
        elif p_val_qd < 0.05:
            print(" * (significant)")
        else:
            print(" (not significant)")
        
        # Max Fitness comparison
        t_stat_fit, p_val_fit = stats.ttest_ind(
            config1_df['final_max_fitness'].values,
            config2_df['final_max_fitness'].values
        )
        
        fit_diff = config1_df['final_max_fitness'].mean() - config2_df['final_max_fitness'].mean()
        fit_pct = (fit_diff / config2_df['final_max_fitness'].mean()) * 100
        
        print(f"\n  Max Fitness:")
        print(f"    {config1['name']}: {config1_df['final_max_fitness'].mean():>10.3f}")
        print(f"    {config2['name']}: {config2_df['final_max_fitness'].mean():>10.3f}")
        print(f"    Difference: {fit_diff:>+10.3f} ({fit_pct:>+6.2f}%)")
        print(f"    t={t_stat_fit:.3f}, p={p_val_fit:.4f}", end="")
        
        if p_val_fit < 0.001:
            print(" *** (highly significant)")
        elif p_val_fit < 0.05:
            print(" * (significant)")
        else:
            print(" (not significant)")

print("\n" + "="*80)
# Out:
# ================================================================================
# PAIRWISE COMPARISONS: DNS-GA SCHEDULES
# ================================================================================
#
# Comparing different g_n values to understand GA frequency impact
# ================================================================================
#
# DNS-GA_g300_gen2 (10 calls) vs DNS-GA_g500_gen2 (6 calls):
#   ======================================================================
#
#   QD Score:
#     DNS-GA_g300_gen2:  410,309.7
#     DNS-GA_g500_gen2:  412,115.0
#     Difference:   -1,805.3 ( -0.44%)
#     t=-0.473, p=0.6489 (not significant)
#
#   Max Fitness:
#     DNS-GA_g300_gen2:    319.333
#     DNS-GA_g500_gen2:    320.008
#     Difference:     -0.675 ( -0.21%)
#     t=-0.076, p=0.9415 (not significant)
#
# DNS-GA_g300_gen2 (10 calls) vs DNS-GA_g1000_gen2 (3 calls):
#   ======================================================================
#
#   QD Score:
#     DNS-GA_g300_gen2:  410,309.7
#     DNS-GA_g1000_gen2:  410,592.4
#     Difference:     -282.8 ( -0.07%)
#     t=-0.091, p=0.9295 (not significant)
#
#   Max Fitness:
#     DNS-GA_g300_gen2:    319.333
#     DNS-GA_g1000_gen2:    319.970
#     Difference:     -0.637 ( -0.20%)
#     t=-0.072, p=0.9447 (not significant)
#
# DNS-GA_g300_gen2 (10 calls) vs DNS-GA_g2000_gen2 (1 calls):
#   ======================================================================
#
#   QD Score:
#     DNS-GA_g300_gen2:  410,309.7
#     DNS-GA_g2000_gen2:  412,361.1
#     Difference:   -2,051.4 ( -0.50%)
#     t=-0.799, p=0.4474 (not significant)
#
#   Max Fitness:
#     DNS-GA_g300_gen2:    319.333
#     DNS-GA_g2000_gen2:    319.908
#     Difference:     -0.575 ( -0.18%)
#     t=-0.060, p=0.9539 (not significant)
#
# DNS-GA_g500_gen2 (6 calls) vs DNS-GA_g1000_gen2 (3 calls):
#   ======================================================================
#
#   QD Score:
#     DNS-GA_g500_gen2:  412,115.0
#     DNS-GA_g1000_gen2:  410,592.4
#     Difference:   +1,522.6 ( +0.37%)
#     t=0.386, p=0.7092 (not significant)
#
#   Max Fitness:
#     DNS-GA_g500_gen2:    320.008
#     DNS-GA_g1000_gen2:    319.970
#     Difference:     +0.038 ( +0.01%)
#     t=0.004, p=0.9965 (not significant)
#
# DNS-GA_g500_gen2 (6 calls) vs DNS-GA_g2000_gen2 (1 calls):
#   ======================================================================
#
#   QD Score:
#     DNS-GA_g500_gen2:  412,115.0
#     DNS-GA_g2000_gen2:  412,361.1
#     Difference:     -246.1 ( -0.06%)
#     t=-0.070, p=0.9463 (not significant)
#
#   Max Fitness:
#     DNS-GA_g500_gen2:    320.008
#     DNS-GA_g2000_gen2:    319.908
#     Difference:     +0.100 ( +0.03%)
#     t=0.011, p=0.9916 (not significant)
#
# DNS-GA_g1000_gen2 (3 calls) vs DNS-GA_g2000_gen2 (1 calls):
#   ======================================================================
#
#   QD Score:
#     DNS-GA_g1000_gen2:  410,592.4
#     DNS-GA_g2000_gen2:  412,361.1
#     Difference:   -1,768.7 ( -0.43%)
#     t=-0.644, p=0.5377 (not significant)
#
#   Max Fitness:
#     DNS-GA_g1000_gen2:    319.970
#     DNS-GA_g2000_gen2:    319.908
#     Difference:     +0.062 ( +0.02%)
#     t=0.007, p=0.9948 (not significant)
#
# ================================================================================

# %% [markdown]
# ### Visualization: Performance by GA Frequency

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Extract g_n values and means for plotting
g_n_values = []
qd_means = []
qd_stds = []
fit_means = []
fit_stds = []

for config in MAIN_CONFIGS:
    config_df = df[df['config_name'] == config['name']]
    g_n_values.append(config['g_n'])
    qd_means.append(config_df['final_qd_score'].mean())
    qd_stds.append(config_df['final_qd_score'].std())
    fit_means.append(config_df['final_max_fitness'].mean())
    fit_stds.append(config_df['final_max_fitness'].std())

# Plot 1: QD Score vs g_n
ax1 = axes[0]
ax1.errorbar(g_n_values, qd_means, yerr=qd_stds, marker='o', markersize=8, 
             linewidth=2, capsize=5, capthick=2, color='#2E86AB')
ax1.set_xlabel('GA Frequency (g_n)', fontsize=12, fontweight='bold')
ax1.set_ylabel('Final QD Score', fontsize=12, fontweight='bold')
ax1.set_title('QD Score vs GA Frequency', fontsize=13, fontweight='bold')
ax1.grid(alpha=0.3)
ax1.set_xscale('log')
ax1.set_xticks(g_n_values)
ax1.set_xticklabels(g_n_values)

# Plot 2: Max Fitness vs g_n
ax2 = axes[1]
ax2.errorbar(g_n_values, fit_means, yerr=fit_stds, marker='s', markersize=8,
             linewidth=2, capsize=5, capthick=2, color='#A23B72')
ax2.set_xlabel('GA Frequency (g_n)', fontsize=12, fontweight='bold')
ax2.set_ylabel('Final Max Fitness', fontsize=12, fontweight='bold')
ax2.set_title('Max Fitness vs GA Frequency', fontsize=13, fontweight='bold')
ax2.grid(alpha=0.3)
ax2.set_xscale('log')
ax2.set_xticks(g_n_values)
ax2.set_xticklabels(g_n_values)

plt.tight_layout()
plt.savefig('ablation_logs/ga_frequency_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("✓ Plot saved to: ablation_logs/ga_frequency_comparison.png")

# %% [markdown]
# ### Key Findings Summary

# %%
print("="*80)
print("KEY FINDINGS: GA FREQUENCY ABLATION")
print("="*80)

# Find best configuration
best_qd_config = None
best_qd_score = -float('inf')

for config in MAIN_CONFIGS:
    config_df = df[df['config_name'] == config['name']]
    mean_qd = config_df['final_qd_score'].mean()
    if mean_qd > best_qd_score:
        best_qd_score = mean_qd
        best_qd_config = config

ga_calls_best = FIXED_PARAMS['num_iterations'] // best_qd_config['g_n']

print(f"\n1. Best Configuration:")
print(f"   {best_qd_config['name']} (g_n={best_qd_config['g_n']}, {ga_calls_best} GA calls)")
print(f"   Mean QD Score: {best_qd_score:,.1f}")

# Analyze trend
print(f"\n2. Performance Trend:")
sorted_configs = sorted(MAIN_CONFIGS, key=lambda x: x['g_n'])
for config in sorted_configs:
    config_df = df[df['config_name'] == config['name']]
    ga_calls = FIXED_PARAMS['num_iterations'] // config['g_n']
    print(f"   g_n={config['g_n']:4d} ({ga_calls:2d} calls): QD={config_df['final_qd_score'].mean():>8,.1f} ± {config_df['final_qd_score'].std():>5.1f}")

# Variance analysis
print(f"\n3. Seed Variability:")
for config in MAIN_CONFIGS:
    config_df = df[df['config_name'] == config['name']]
    cv = (config_df['final_qd_score'].std() / config_df['final_qd_score'].mean()) * 100
    ga_calls = FIXED_PARAMS['num_iterations'] // config['g_n']
    print(f"   {config['name']} ({ga_calls} calls): CV = {cv:.2f}%")

print("\n" + "="*80)
print("CONCLUSION:")
print("  • Compare QD scores across different GA frequencies (g_n=300, 500, 1000, 2000)")
print("  • Identify optimal balance between GA frequency and final performance")
print("  • Assess whether more frequent GA calls improve or degrade QD score")
print("="*80)
